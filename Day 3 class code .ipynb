# %%
tuple = ( "maths" , "electricity" , "it")
print(type(tuple) )
print (tuple)
# Out:
# <class 'tuple'>
# ('maths', 'electricity', 'it')

# %%
set = {"arabic" , "maths" , "it" , "english"}
print(set)
# Out:
# {'english', 'it', 'arabic', 'maths'}

# %%
dict = {"name":"john" , "school":"weschool" , "grade":"2"}
print (dict)
# Out:
# {'name': 'john', 'school': 'weschool', 'grade': '2'}

# %%
print ( dict.items())
# Out:
# dict_items([('name', 'john'), ('school', 'weschool'), ('grade', '2')])

# %%
print ( dict.keys())
# Out:
# dict_keys(['name', 'school', 'grade'])

# %%
x = 10
y = 35

if (x > y):
    print("x is greater than y")
elif (x == y):
    print ("x is equal y")
else:
    print("x is less than y")
# Out:
# x is less than y

# %%
a = float ( input("enter number") )

if (a > 0):
    print ("positve")
elif (a == 0):
    print ("zero")
else:
    print ("negative")
# Out:
# enter number -2
# negative

# %%
i = 1

while (i < 6):
    print(i)
    i = i + 1
# Out:
# 1
# 2
# 3
# 4
# 5
