# %%
print ("hello")
# Out:
# hello

# %%
#print ("hello")

# %%
#variables
x = 5
y = "we school"
print (x)
print (y)
print ("x")
# Out:
# 5
# we school
# x

# %%
X = 3
x = 5 
print (X)
print (x)
# Out:
# 3
# 5

# %%
x , y , z = "red" , "blue" , "green"
print ( x , y , z)
# Out:
# red blue green

# %%
x = "awesome"
print ("python is" +x)
# Out:
# python isawesome

# %%
x = "python is" 
y = "awesome"
print (x+y)
# Out:
# python isawesome

# %%
text = "future career camp , python , group 4"
print(len (text) )
print("camp" in text)
print(text.upper() )
print(text.lower() )
print(text.strip() )
print(text.split(",") )
print (text.replace("4" , "5") )
# Out:
# 37
# True
# FUTURE CAREER CAMP , PYTHON , GROUP 4
# future career camp , python , group 4
# future career camp , python , group 4
# ['future career camp ', ' python ', ' group 4']
# future career camp , python , group 5

# %%
x = "camp"
y = "python"
z = 4
print("future Career {} , {} , group {}".format(x , y , z) )
print("hello {}".format("world") )
# Out:
# future Career camp , python , group 4
# hello world

# %%
x = 6
x = 1000000
x = 9

x = 5.8
x = 9.0

# %%
print (5+2)
# Out:
# 7

# %%
print (5-2)
# Out:
# 3

# %%
print (5*3)
# Out:
# 15

# %%
# / float
print (5/2)
# Out:
# 2.5

# %%
# // intger
print (5//2)
# Out:
# 2

# %%
print (5 % 2)
# Out:
# 1

# %%
print (4 % 2)
# Out:
# 0

# %%
print ( 5+3/2*(3-1) )
# Out:
# 8.0

# %%
x = "we school"
print (type (x) )
# Out:
# <class 'str'>

# %%
x = 5
y = 6.5
print( type(x) )
print( type(y) )
# Out:
# <class 'int'>
# <class 'float'>

# %%
#casting
y = int(2.8)
print (y)
# Out:
# 2

# %%
x = float (5)
print (x)
# Out:
# 5.0

# %%
z = str(5)
print(z)
print ( type (z) )
# Out:
# 5
# <class 'str'>

# %%
name = input ("type you name")
print(type(name))
# Out:
# type you name abdelrahman
# <class 'str'>

# %%
x = input ("type a number")
print (type(x))
y = int(x)
y + 3
# Out:
# type a number 5
# <class 'str'>
# 8

# %%
a = input ("type a number")
# Out:
# type a number 6

# %%
print (type(a))
# Out:
# <class 'str'>

# %%
b = int(a)
print (type(b))
# Out:
# <class 'int'>

# %%
b + 3
# Out:
# 9

# %%
X = True
print( type(X) )
# Out:
# <class 'bool'>

# %%
X = False
print(type(X))
# Out:
# <class 'bool'>

# %%
X = True
print(type (X))
# Out:
# <class 'bool'>

# %%
x = ["maths" , "pe" , "physics" , "it" , "electricity"]
print (x)
# Out:
# ['maths', 'pe', 'physics', 'it', 'electricity']

# %%
print ( x[0])
# Out:
# maths

# %%
print( x[-3] )
# Out:
# physics

# %%
print ( x[1:4])
# Out:
# ['pe', 'physics', 'it']

# %%
print ( x[0:3])
# Out:
# ['maths', 'pe', 'physics']

# %%
#nagative index
print ( x[-1])
# Out:
# electricity

# %%
print ( x[2])
# Out:
# physics

# %%
print (x[4])
# Out:
# electricity

# %%
x = ["maths" , "pe" , "physics" , "it" , "electricity"]
#modify items
x[2] = "communications"
print (x)
# Out:
# ['maths', 'pe', 'communications', 'it', 'electricity']

# %%
x = ["maths" , "pe" , "physics" , "it" , "electricity"]
#modify items
y = input("")
x[2] = y
print (x)
# Out:
#  communications
# ['maths', 'pe', 'communications', 'it', 'electricity']

# %%
x[0:2] = "english" , "pe"
print (x)
# Out:
# ['english', 'pe', 'communications', 'it', 'electricity']

# %%
x = ["maths" , "pe" , "physics" , "it" , "electricity"]
x.append("arabic")
print (x)
# Out:
# ['maths', 'pe', 'physics', 'it', 'electricity', 'arabic']

# %%
x.insert(1 , "social skills")
print (x)
# Out:
# ['maths', 'social skills', 'social skills', 'pe', 'physics', 'it', 'electricity', 'arabic']

# %%
x.remove("physics")
print (x)
# Out:
# ['maths', 'social skills', 'social skills', 'pe', 'it', 'electricity', 'arabic']

# %%
x = ["maths" , "pe" , "physics" , "it" , "electricity"]
x.pop(2)
print (x)
# Out:
# ['maths', 'pe', 'it', 'electricity']

# %%
y = [5 , 8 , 1 , 4 , 10]
y.sort(reverse = True)
print (y)
# Out:
# [10, 8, 5, 4, 1]

# %%
list1 = [1,2,3]
list2 = [4,5,6,7]
list1.extend(list2)
print (list1)
# Out:
# [1, 2, 3, 4, 5, 6, 7]
